# %% [markdown]
# This notebook contains the search tree for comparing UCS and A* search. There are also two sets of heuristics.

# %%
searchTree = [('S','A',5),
              ('S','B',7),
              ('A','C',10),
              ('A','G',15),
              ('A','E',7),
              ('C','I',15),
              ('E','J',4),
              ('E','K',7),
              ('K','M',4),
              ('B','F',4),
              ('B','H',6),
              ('H','G',2),
              ('H','L',7)]

heuristics1 = [('A',15),
               ('C',10),
               ('L',4),
               ('E',9),
               ('J',7),
               ('K',4),
               ('M',8),
               ('B',20),
               ('F',7),
               ('H',2),
               ('L',5)]

heuristics2 = [('A',15),
               ('C',8),
               ('L',4),
               ('E',9),
               ('J',7),
               ('K',10),
               ('M',8),
               ('B',9),
               ('F',7),
               ('H',2),
               ('L',14)]
