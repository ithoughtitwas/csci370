# %% [markdown]
# The purpose of this notebook is to demonstrate how to read a dataset from a local computer. Be careful to enter the filename when prompted exactly as what's in the read_csv.

# %%
from google.colab import files
import io
import pandas as pd

uploaded = files.upload()
mydf = pd.read_csv(io.BytesIO(uploaded['carBuyData2.csv']))
print(mydf)
