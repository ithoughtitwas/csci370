# %% [markdown]
# You're here. Good! The purpose of this notebook is to simply run the following code cell. Press the Run cell button (that triangle-looking thing when you hover your mouse over the following cell). What's output?

# %%
import requests

url = 'https://raw.githubusercontent.com/ithoughtitwas/csci370/main/data/whatitsays.txt'
page = requests.get(url)
print(page.text)
